# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

quantized_model_path = "./tmp_autoround/Qwen2.5-1.5B-Instruct-w4g128"
model = AutoModelForCausalLM.from_pretrained(quantized_model_path,
                                             device_map="auto", torch_dtype="auto")
tokenizer = AutoTokenizer.from_pretrained(quantized_model_path)
text = "There is a girl who likes adventure,"
inputs = tokenizer(text, return_tensors="pt").to(model.device)
print(tokenizer.decode(model.generate(**inputs, max_new_tokens=50)[0]))
# Out:
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/qat_with_lora/venv/lib/python3.11/site-packages/auto_gptq/nn_modules/triton_utils/kernels.py:410: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/qat_with_lora/venv/lib/python3.11/site-packages/auto_gptq/nn_modules/triton_utils/kernels.py:418: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @custom_bwd
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/qat_with_lora/venv/lib/python3.11/site-packages/auto_gptq/nn_modules/triton_utils/kernels.py:461: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float16)
# ...

# %%
print(tokenizer.decode(model.generate(**inputs, max_new_tokens=50)[0]))
# Out:
# There is a girl who likes adventure, and she enjoys exploring different places. She plans to go on an expedition in the Amazon rainforest next month. What are some of her potential risks and challenges that she should be aware of before embarking on this journey?
# 1. The dangers of insects

# %%
# from lm_eval.models.optimum_lm import OptimumLM
# from lm_eval.models.optimum_lm import HFLM
from lm_eval import simple_evaluate

lm_obj = OptimumLM(pretrained=model, max_length=4096)
from time import time
s = time()
results = simple_evaluate(lm_obj, tasks=['wikitext'], log_samples=False)
print(results, time() - s)
# Out:
# [Task: wikitext] metric word_perplexity is defined, but aggregation is not. using default aggregation=weighted_perplexity
# [Task: wikitext] metric word_perplexity is defined, but higher_is_better is not. using default higher_is_better=False
# [Task: wikitext] metric byte_perplexity is defined, but aggregation is not. using default aggregation=weighted_perplexity
# [Task: wikitext] metric byte_perplexity is defined, but higher_is_better is not. using default higher_is_better=False
# [Task: wikitext] metric bits_per_byte is defined, but aggregation is not. using default aggregation=bits_per_byte
# [Task: wikitext] metric bits_per_byte is defined, but higher_is_better is not. using default higher_is_better=False
# ...
# Running loglikelihood requests: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.42it/s]
# ...

# %%
import json
s = time()
results = simple_evaluate(lm_obj, tasks=['gsm8k'], log_samples=False)
print(results)
print(f"Took {(time() - s)//60:.2f} min")
print(json.dumps(results, indent=4))
