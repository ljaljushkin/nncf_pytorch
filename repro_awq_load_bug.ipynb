# %%
s = '/nfs/site/home/kprokofi/MODEL_DIR/Phi-3_5-mini-instruct/FQ_emb_head_int8_int4_asym_rank256_gs64_se_awq_test/nncf_checkpoint.pth'
import torch

# %%
t = torch.load(s)
# Out:
# /tmp/ipykernel_511446/560160184.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   t = torch.load(s)

# %%
t.keys()
# Out:
# dict_keys(['nncf_state_dict', 'nncf_config'])

# %%
c = t['nncf_config']

# %%
c.keys()
# Out:
# dict_keys(['compression_state', 'trace_parameters'])

# %%
cs = c['compression_state']

# %%
cs
# Out:
# [{'type': 'PTSharedFnInsertionCommand',
#   'target_points': [{'target_type': {'name': 'OPERATOR_PRE_HOOK'},
#     'input_port_id': 0,
#     'target_node_name': 'Phi3ForCausalLM/Phi3Model[model]/ModuleList[layers]/Phi3DecoderLayer[20]/Phi3MLP[mlp]/__mul___0'}],
#   'op_name': 'Phi3ForCausalLM/Phi3Model[model]/ModuleList[layers]/Phi3DecoderLayer[20]/Phi3MLP[mlp]/SiLU[activation_fn]/silu_0/awq_mul',
#   'compression_module_type': 1,
#   'compression_module_name': 'SQMultiply',
#   'fn_config': {'scale_shape': [1, 8192]},
#   'hooks_group_name': 'default_hooks_group',
#   'priority': 0},
#  {'type': 'PTSharedFnInsertionCommand',
#   'target_points': [{'target_type': {'name': 'OPERATOR_PRE_HOOK'},
#     'input_port_id': 0,
#     'target_node_name': 'Phi3ForCausalLM/Phi3Model[model]/ModuleList[layers]/Phi3DecoderLayer[15]/Phi3MLP[mlp]/__mul___0'}],
#   'op_name': 'Phi3ForCausalLM/Phi3Model[model]/ModuleList[layers]/Phi3DecoderLayer[15]/Phi3MLP[mlp]/SiLU[activation_fn]/silu_0/awq_mul',
# ...

# %%
import nncf
# Out:
# <frozen importlib.util>:247: DeprecationWarning: The `openvino.runtime` module is deprecated and will be removed in the 2026.0 release. Please replace `openvino.runtime` with `openvino`.
# WARNING:nncf:NNCF provides best results with torch==2.6.*, while current torch version is 2.5.1+cu121. If you encounter issues, consider switching to torch==2.6.*

# %%
from nncf.torch.layer_utils import COMPRESSION_MODULES

# %%
COMPRESSION_MODULES.registry_dict
# Out:
# {'SymmetricQuantizer': nncf.torch.quantization.layers.SymmetricQuantizer,
#  'AsymmetricQuantizer': nncf.torch.quantization.layers.AsymmetricQuantizer,
#  'AsymmetricLoraQuantizer': nncf.torch.quantization.layers.AsymmetricLoraQuantizer,
#  'SymmetricLoraQuantizer': nncf.torch.quantization.layers.SymmetricLoraQuantizer,
#  'BinaryMask': nncf.torch.sparsity.layers.BinaryMask,
#  'RBSparsifyingWeight': nncf.torch.sparsity.rb.layers.RBSparsifyingWeight,
#  'MovementSparsifier': nncf.experimental.torch.sparsity.movement.layers.MovementSparsifier,
#  'FilterPruningMask': nncf.torch.pruning.filter_pruning.layers.FilterPruningMask,
#  'SQMultiply': nncf.quantization.algorithms.smooth_quant.torch_backend.SQMultiply}
