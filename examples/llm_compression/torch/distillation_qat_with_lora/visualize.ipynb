# %%
# go over all files in s, find *.json file and create a DataFrame with the following structure:
    # Name | wikitext | hellaswag | gsm8k
    # out_meta-llama_Llama-3_2-3B-Instruct_repro_r256_alpha | 1 | 2 | 3 |
    # out_meta-llama_Llama-3_2-3B-Instruct_repro_r256_t2 | 3 | 2 | 3 |

# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/
    # out_meta-llama_Llama-3_2-3B-Instruct_repro_r256_alpha/
        # last/
            # results_hellaswag.json

# {
#     "results": {
#         "wikitext": {
#             "alias": "wikitext",
#             "word_perplexity,none": 13.160949160720696,

# {
#     "results": {
#         "hellaswag": {
#             "alias": "hellaswag",
#             "acc,none": 0.5163314080860386,

from pathlib import Path
import pandas as pd
import json

# Directory to search
search_dir = Path("/local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora")

# Prepare data list
data = []

# Iterate over all .json files in the directory (recursively)
for json_file in search_dir.rglob('**/results_*.json'):
    print(json_file)
    with open(json_file, 'r', encoding='utf-8') as f:
        content = json.load(f)
    # Extract values, default to None if not present
    name = json_file.parent.parent.stem
    wikitext = content.get('results', {}).get('wikitext', {}).get('word_perplexity,none')
    hellaswag = content.get('results', {}).get('hellaswag', {}).get('acc,none')
    gsm8k_sm = content.get('results', {}).get('gsm8k', {}).get('exact_match,strict-match')
    gsm8k_fm = content.get('results', {}).get('gsm8k', {}).get('exact_match,flexible-extract')

    data.append({
        'Name': name,
        'wikitext': wikitext,
        'hellaswag': hellaswag,
        'gsm8k_sm': gsm8k_sm,
        'gsm8k_fm': gsm8k_fm
    })

# Create DataFrame
df = pd.DataFrame(data, columns=['Name', 'wikitext', 'hellaswag', 'gsm8k_sm', 'gsm8k_fm'])
print(df)

pt = df.pivot_table(index='Name', values=['wikitext', 'hellaswag', 'gsm8k_sm', 'gsm8k_fm'])
print(pt)
pt.to_csv('/local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/tmp.csv')
# Out:
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_meta-llama_Llama-3_2-3B-Instruct_repro_r32_alpha_t2/last/results_wikitext.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_meta-llama_Llama-3_2-3B-Instruct_repro_r32_alpha_t2/last/results_hellaswag.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_meta-llama_Llama-3_2-3B-Instruct_repro_r32_alpha_t2/last/results_gsm8k.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_microsoft_Phi-3_5-mini-instruct_repro_r32_alpha_t2/last/results_wikitext.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_microsoft_Phi-3_5-mini-instruct_repro_r32_alpha_t2/last/results_hellaswag.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_microsoft_Phi-3_5-mini-instruct_repro_r32_alpha_t2/last/results_gsm8k.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out/auto_round_phi3_5/Phi-3.5-mini-instruct-w4g128/gsm8k.json/results_2025-06-18T22-47-16.922201.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out/auto_round_phi3_5/Phi-3.5-mini-instruct-w4g128/wikitext.json/results_2025-06-18T22-29-15.148875.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out/auto_round_phi3_5/Phi-3.5-mini-instruct-w4g128/hellaswag.json/results_2025-06-18T22-32-55.116378.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_microsoft_Phi-3_5-mini-instruct_repro_r32_alpha/last/results_wikitext.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_microsoft_Phi-3_5-mini-instruct_repro_r32_alpha/last/results_hellaswag.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_microsoft_Phi-3_5-mini-instruct_repro_r32_alpha/last/results_gsm8k.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_Qwen_Qwen2_5-1_5B-Instruct_repro_r32_t2/last/results_wikitext.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_Qwen_Qwen2_5-1_5B-Instruct_repro_r32_t2/last/results_hellaswag.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_Qwen_Qwen2_5-1_5B-Instruct_repro_r32_t2/last/results_gsm8k.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_Qwen_Qwen2_5-1_5B-Instruct_repro_r256_alpha/last/results_wikitext.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_Qwen_Qwen2_5-1_5B-Instruct_repro_r256_alpha/last/results_hellaswag.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_Qwen_Qwen2_5-1_5B-Instruct_repro_r256_alpha/last/results_gsm8k.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_Qwen_Qwen2_5-1_5B-Instruct_repro_r256_alpha_t2/last/results_wikitext.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_Qwen_Qwen2_5-1_5B-Instruct_repro_r256_alpha_t2/last/results_hellaswag.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_Qwen_Qwen2_5-1_5B-Instruct_repro_r256_alpha_t2/last/results_gsm8k.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_microsoft_Phi-3_5-mini-instruct_repro_r32_t2/last/results_wikitext.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_microsoft_Phi-3_5-mini-instruct_repro_r32_t2/last/results_hellaswag.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_microsoft_Phi-3_5-mini-instruct_repro_r32_t2/last/results_gsm8k.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_microsoft_Phi-3_5-mini-instruct_repro_r32/last/results_wikitext.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_microsoft_Phi-3_5-mini-instruct_repro_r32/last/results_hellaswag.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_microsoft_Phi-3_5-mini-instruct_repro_r32/last/results_gsm8k.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_meta-llama_Llama-3_2-3B-Instruct_repro_r256_alpha_t2/last/results_wikitext.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_meta-llama_Llama-3_2-3B-Instruct_repro_r256_alpha_t2/last/results_hellaswag.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_meta-llama_Llama-3_2-3B-Instruct_repro_r256_alpha_t2/last/results_gsm8k.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_microsoft_Phi-3_5-mini-instruct_repro_r256_alpha/last/results_wikitext.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_microsoft_Phi-3_5-mini-instruct_repro_r256_alpha/last/results_hellaswag.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_microsoft_Phi-3_5-mini-instruct_repro_r256_alpha/last/results_gsm8k.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_Qwen_Qwen2_5-1_5B-Instruct_repro_r256_t2/last/results_wikitext.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_Qwen_Qwen2_5-1_5B-Instruct_repro_r256_t2/last/results_hellaswag.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_Qwen_Qwen2_5-1_5B-Instruct_repro_r256_t2/last/results_gsm8k.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_microsoft_Phi-3_5-mini-instruct_repro_r256/last/results_wikitext.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_microsoft_Phi-3_5-mini-instruct_repro_r256/last/results_hellaswag.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_microsoft_Phi-3_5-mini-instruct_repro_r256/last/results_gsm8k.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_meta-llama_Llama-3_2-3B-Instruct_repro_r32/last/results_wikitext.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_meta-llama_Llama-3_2-3B-Instruct_repro_r32/last/results_hellaswag.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_meta-llama_Llama-3_2-3B-Instruct_repro_r32/last/results_gsm8k.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_Qwen_Qwen2_5-1_5B-Instruct_repro_r32/last/results_wikitext.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_Qwen_Qwen2_5-1_5B-Instruct_repro_r32/last/results_hellaswag.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_Qwen_Qwen2_5-1_5B-Instruct_repro_r32/last/results_gsm8k.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_microsoft_Phi-3_5-mini-instruct_repro_r256_alpha_t2/last/results_wikitext.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_microsoft_Phi-3_5-mini-instruct_repro_r256_alpha_t2/last/results_hellaswag.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_microsoft_Phi-3_5-mini-instruct_repro_r256_alpha_t2/last/results_gsm8k.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_meta-llama_Llama-3_2-3B-Instruct_repro_r32_alpha/last/results_wikitext.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_meta-llama_Llama-3_2-3B-Instruct_repro_r32_alpha/last/results_hellaswag.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_meta-llama_Llama-3_2-3B-Instruct_repro_r32_alpha/last/results_gsm8k.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_microsoft_Phi-3_5-mini-instruct_repro_r256_t2/last/results_wikitext.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_microsoft_Phi-3_5-mini-instruct_repro_r256_t2/last/results_hellaswag.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_microsoft_Phi-3_5-mini-instruct_repro_r256_t2/last/results_gsm8k.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_meta-llama_Llama-3_2-3B-Instruct_repro_r256_t2/last/results_wikitext.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_meta-llama_Llama-3_2-3B-Instruct_repro_r256_t2/last/results_hellaswag.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_meta-llama_Llama-3_2-3B-Instruct_repro_r256_t2/last/results_gsm8k.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_meta-llama_Llama-3_2-3B-Instruct_repro_r256_alpha/last/results_wikitext.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_meta-llama_Llama-3_2-3B-Instruct_repro_r256_alpha/last/results_hellaswag.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_meta-llama_Llama-3_2-3B-Instruct_repro_r256_alpha/last/results_gsm8k.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_Qwen_Qwen2_5-1_5B-Instruct_repro_r256/last/results_wikitext.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_Qwen_Qwen2_5-1_5B-Instruct_repro_r256/last/results_hellaswag.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_Qwen_Qwen2_5-1_5B-Instruct_repro_r256/last/results_gsm8k.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_meta-llama_Llama-3_2-3B-Instruct_repro_r256/last/results_wikitext.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_meta-llama_Llama-3_2-3B-Instruct_repro_r256/last/results_hellaswag.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_meta-llama_Llama-3_2-3B-Instruct_repro_r256/last/results_gsm8k.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_meta-llama_Llama-3_2-3B-Instruct_repro_r32_t2/last/results_wikitext.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_meta-llama_Llama-3_2-3B-Instruct_repro_r32_t2/last/results_hellaswag.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_meta-llama_Llama-3_2-3B-Instruct_repro_r32_t2/last/results_gsm8k.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_Qwen_Qwen2_5-1_5B-Instruct_repro_r32_alpha_t2/last/results_wikitext.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_Qwen_Qwen2_5-1_5B-Instruct_repro_r32_alpha_t2/last/results_hellaswag.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_Qwen_Qwen2_5-1_5B-Instruct_repro_r32_alpha_t2/last/results_gsm8k.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_Qwen_Qwen2_5-1_5B-Instruct_repro_r32_alpha/last/results_wikitext.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_Qwen_Qwen2_5-1_5B-Instruct_repro_r32_alpha/last/results_hellaswag.json
# /local_ssd2/nlyalyus/projects/nncf/examples/llm_compression/torch/distillation_qat_with_lora/out_Qwen_Qwen2_5-1_5B-Instruct_repro_r32_alpha/last/results_gsm8k.json
#                                                  Name   wikitext  hellaswag  \
# 0   out_meta-llama_Llama-3_2-3B-Instruct_repro_r32...  13.046828        NaN
# 1   out_meta-llama_Llama-3_2-3B-Instruct_repro_r32...        NaN   0.516531
# 2   out_meta-llama_Llama-3_2-3B-Instruct_repro_r32...        NaN        NaN
# 3   out_microsoft_Phi-3_5-mini-instruct_repro_r32_...  11.382307        NaN
# 4   out_microsoft_Phi-3_5-mini-instruct_repro_r32_...        NaN   0.569906
# ..                                                ...        ...        ...
# 70  out_Qwen_Qwen2_5-1_5B-Instruct_repro_r32_alpha_t2        NaN   0.493627
# 71  out_Qwen_Qwen2_5-1_5B-Instruct_repro_r32_alpha_t2        NaN        NaN
# 72     out_Qwen_Qwen2_5-1_5B-Instruct_repro_r32_alpha  13.340232        NaN
# 73     out_Qwen_Qwen2_5-1_5B-Instruct_repro_r32_alpha        NaN   0.496813
# 74     out_Qwen_Qwen2_5-1_5B-Instruct_repro_r32_alpha        NaN        NaN
#
#     gsm8k_sm  gsm8k_fm
# 0        NaN       NaN
# 1        NaN       NaN
# 2   0.272176  0.648976
# 3        NaN       NaN
# 4        NaN       NaN
# ..       ...       ...
# 70       NaN       NaN
# 71  0.096285  0.450341
# 72       NaN       NaN
# 73       NaN       NaN
# 74  0.103867  0.464746
#
# [75 rows x 5 columns]

# %%
df['Name']
# Out:
# 0     out_meta-llama_Llama-3_2-3B-Instruct_repro_r32...
# 1     out_meta-llama_Llama-3_2-3B-Instruct_repro_r32...
# 2     out_meta-llama_Llama-3_2-3B-Instruct_repro_r32...
# 3     out_microsoft_Phi-3_5-mini-instruct_repro_r32_...
# 4     out_microsoft_Phi-3_5-mini-instruct_repro_r32_...
#                             ...
# 67    out_Qwen_Qwen2_5-1_5B-Instruct_repro_r32_alpha_t2
# 68    out_Qwen_Qwen2_5-1_5B-Instruct_repro_r32_alpha_t2
# 69       out_Qwen_Qwen2_5-1_5B-Instruct_repro_r32_alpha
# 70       out_Qwen_Qwen2_5-1_5B-Instruct_repro_r32_alpha
# 71       out_Qwen_Qwen2_5-1_5B-Instruct_repro_r32_alpha
# Name: Name, Length: 72, dtype: object

# %%
# Out:
#                                                     gsm8k_fm  gsm8k_sm  \
# Name
# out_Qwen_Qwen2_5-1_5B-Instruct_repro_r256           0.408643  0.040182
# out_Qwen_Qwen2_5-1_5B-Instruct_repro_r256_alpha     0.471569  0.100834
# out_Qwen_Qwen2_5-1_5B-Instruct_repro_r256_alpha_t2  0.442002  0.092494
# out_Qwen_Qwen2_5-1_5B-Instruct_repro_r256_t2        0.416983  0.043973
# out_Qwen_Qwen2_5-1_5B-Instruct_repro_r32            0.408643  0.037908
# out_Qwen_Qwen2_5-1_5B-Instruct_repro_r32_alpha      0.464746  0.103867
# out_Qwen_Qwen2_5-1_5B-Instruct_repro_r32_alpha_t2   0.450341  0.096285
# out_Qwen_Qwen2_5-1_5B-Instruct_repro_r32_t2         0.406368  0.033359
# out_meta-llama_Llama-3_2-3B-Instruct_repro_r256     0.623958  0.277483
# out_meta-llama_Llama-3_2-3B-Instruct_repro_r256...  0.670963  0.289613
# out_meta-llama_Llama-3_2-3B-Instruct_repro_r256...  0.643669  0.257771
# out_meta-llama_Llama-3_2-3B-Instruct_repro_r256_t2  0.589841  0.257013
# out_meta-llama_Llama-3_2-3B-Instruct_repro_r32      0.584534  0.282790
# out_meta-llama_Llama-3_2-3B-Instruct_repro_r32_...  0.664898  0.283548
# out_meta-llama_Llama-3_2-3B-Instruct_repro_r32_...  0.648976  0.272176
# out_meta-llama_Llama-3_2-3B-Instruct_repro_r32_t2   0.575436  0.269143
# out_microsoft_Phi-3_5-mini-instruct_repro_r256      0.721759  0.640637
# out_microsoft_Phi-3_5-mini-instruct_repro_r256_...  0.750569  0.671721
# out_microsoft_Phi-3_5-mini-instruct_repro_r256_...  0.742229  0.652009
# out_microsoft_Phi-3_5-mini-instruct_repro_r256_t2   0.721001  0.637604
# out_microsoft_Phi-3_5-mini-instruct_repro_r32       0.728582  0.664898
# out_microsoft_Phi-3_5-mini-instruct_repro_r32_a...  0.744503  0.673995
# out_microsoft_Phi-3_5-mini-instruct_repro_r32_a...  0.742987  0.676270
# out_microsoft_Phi-3_5-mini-instruct_repro_r32_t2    0.726308  0.653525
#
#                                                     hellaswag   wikitext
# Name
# out_Qwen_Qwen2_5-1_5B-Instruct_repro_r256            0.492631  13.939333
# out_Qwen_Qwen2_5-1_5B-Instruct_repro_r256_alpha      0.495519  13.365349
# out_Qwen_Qwen2_5-1_5B-Instruct_repro_r256_alpha_t2   0.493826  13.420780
# out_Qwen_Qwen2_5-1_5B-Instruct_repro_r256_t2         0.492332  13.931013
# out_Qwen_Qwen2_5-1_5B-Instruct_repro_r32             0.493029  13.885015
# out_Qwen_Qwen2_5-1_5B-Instruct_repro_r32_alpha       0.496813  13.340232
# out_Qwen_Qwen2_5-1_5B-Instruct_repro_r32_alpha_t2    0.493627  13.396838
# out_Qwen_Qwen2_5-1_5B-Instruct_repro_r32_t2          0.491536  13.888972
# out_meta-llama_Llama-3_2-3B-Instruct_repro_r256      0.513444  13.373798
# out_meta-llama_Llama-3_2-3B-Instruct_repro_r256...   0.516331  13.160949
# out_meta-llama_Llama-3_2-3B-Instruct_repro_r256...   0.516033  13.142858
# out_meta-llama_Llama-3_2-3B-Instruct_repro_r256_t2   0.513742  13.384873
# out_meta-llama_Llama-3_2-3B-Instruct_repro_r32       0.514439  13.324789
# out_meta-llama_Llama-3_2-3B-Instruct_repro_r32_...   0.516431  12.930919
# out_meta-llama_Llama-3_2-3B-Instruct_repro_r32_...   0.516531  13.046828
# out_meta-llama_Llama-3_2-3B-Instruct_repro_r32_t2    0.513543  13.346289
# out_microsoft_Phi-3_5-mini-instruct_repro_r256       0.583848  12.461018
# out_microsoft_Phi-3_5-mini-instruct_repro_r256_...   0.570803  11.181302
# out_microsoft_Phi-3_5-mini-instruct_repro_r256_...   0.570504  11.408878
# out_microsoft_Phi-3_5-mini-instruct_repro_r256_t2    0.584844  12.470381
# out_microsoft_Phi-3_5-mini-instruct_repro_r32        0.582752  12.372379
# out_microsoft_Phi-3_5-mini-instruct_repro_r32_a...   0.572097  11.132532
# out_microsoft_Phi-3_5-mini-instruct_repro_r32_a...   0.569906  11.382307
# out_microsoft_Phi-3_5-mini-instruct_repro_r32_t2     0.584943  12.394002

# %%
data[0]
# Out:
# {'Name': 'out_meta-llama_Llama-3_2-3B-Instruct_repro_r32_alpha_t2',
#  'wikitext': 13.04682771996109,
#  'hellaswag': None,
#  'gsm8k_sm': None,
#  'gsm8k_fm': None}

# %%
for key in ['wikitext', 'hellaswag', 'gsm8k']:
    if key in content:
        data.append({'Name': name, 'Type': key, 'Value': content[key]})

df = pd.DataFrame(data)
pivot_df = df.pivot_table(index='Name', columns='Type', values='Value', aggfunc='first').reset_index()
print(pivot_df)
